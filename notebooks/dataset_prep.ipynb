# %% [markdown]
# ## Setup

# %%
# Import libraries
import hashlib
import os
from pathlib import Path
from shutil import copy2

import pandas as pd
from tqdm.auto import tqdm

# %%
# Define data path and class map
subclass = True
downsample = True
finetune = True
dataset_suffix = "4000"
data_dir = Path(
    "..",
    "..",
    "datasets",
    f"coco{dataset_suffix}{'_subclass' if subclass else ''}{'_downsample' if downsample else ''}{'_finetune' if finetune else ''}",
)
downsample_train2017 = 0.95
downsample_val2017 = 0.8
class_map = {"0": "0", "15": "1"}
if not data_dir.exists():
    raise ValueError(f"Data directory {data_dir} does not exist")

# %%
# Clear cache
for p in Path(data_dir).rglob("*.cache"):
    os.remove(p)

# %%
# Get all .txt or .jpg files
def get_files(subfolder, type="labels"):
    match type:
        case "labels":
            files = [p for p in Path(data_dir).rglob("*.txt") if p.stem.isdigit()]
        case "images":
            files = [p for p in Path(data_dir).rglob("*.jpg") if p.stem.isdigit()]
    if subfolder is not None:
        data_dir_parts = Path(data_dir).parts
        files = [f for f in files if subfolder in f.parts[len(data_dir_parts) :]]
    if not files:
        raise ValueError("No files found")
    return files

# %%
# Get information about each annotation
def get_metadata(subfolder):

    # initialise output
    ann_meta = []

    # loop over all label files
    for txt_file in tqdm(get_files(subfolder=subfolder), desc="Get Metadata"):

        # open file
        with open(txt_file, "r") as f:
            lines = f.readlines()

        # loop over all lines in file
        for line in lines:

            # split out label components
            parts = line.split()
            class_id = parts.pop(0)
            ann_meta.append((str(txt_file), class_id))

    # convert to dataframe
    ann_meta = pd.DataFrame(ann_meta, columns=["filepath", "class"])
    ann_meta["split"] = ann_meta["filepath"].map(lambda x: x.split("/")[5][:-4])
    ann_meta["filenames"] = ann_meta["filepath"].map(lambda x: x.split("/")[-1])

    # identify classes in each file
    file_meta = (
        ann_meta.groupby("filepath")["class"]
        .unique()
        .map(lambda x: ",".join([str(s) for s in sorted(x)]))
    )

    # identify background only images
    background_path = list(
        {str(s) for s in get_files(type="images", subfolder=subfolder)}
        - {p.replace("labels", "images").replace("txt", "jpg") for p in file_meta.index}
    )
    file_meta = pd.concat([file_meta, pd.Series("", index=background_path)])

    return ann_meta, file_meta

# %%
# Remap labels in a label file
def remap_labels(txt_file):

    # initialise output
    filtered_lines = []

    # open file
    with open(txt_file, "r") as f:
        lines = f.readlines()

    # loop over all lines in file
    for line in lines:

        # split out label components
        parts = line.split()

        # ignore undesirable classes and remap
        if parts[0] in class_map:
            parts[0] = str(class_map[parts[0]])
            filtered_lines.append(" ".join(parts) + "\n")

    # write back to disk
    if filtered_lines:
        with open(txt_file, "w") as f:
            f.writelines(filtered_lines)
    else:
        os.remove(txt_file)

# %% [markdown]
# ## Dataset changes

# %%
# Subset classes and remap ids

if subclass:
    for txt_file in tqdm(get_files(subfolder=None)):
        remap_labels(txt_file)

# %%
# Downsample popular classes

if downsample:
    # loop over subsets
    for downsample_subfolder, downsample in [
        ("val2017", downsample_val2017),
        ("train2017", downsample_train2017),
    ]:

        # get metadata
        ann_meta, file_meta = get_metadata(subfolder=downsample_subfolder)

        # remove some images that only contain people
        for p in file_meta.loc[file_meta == "0"].index.tolist():
            if (
                int(hashlib.sha256(p.encode("utf-8")).hexdigest(), 16) / (2**256 - 1)
            ) < downsample:
                os.remove(p.replace("labels", "images").replace("txt", "jpg"))
                os.remove(p)

        # remove some images that only contain background
        for p in file_meta.loc[file_meta == ""].index.tolist():
            if (
                int(hashlib.sha256(p.encode("utf-8")).hexdigest(), 16) / (2**256 - 1)
            ) < downsample:
                os.remove(p)

# %%
# Copy finetune data

if finetune:

    target_dir = Path(data_dir)

    for suffix in ["", "_cropped"]:
        source_dir = Path("..", "datasets", f"finetune_data{suffix}")

        for src_file in tqdm(list(source_dir.rglob("*")), desc="Copy data"):

            if src_file.is_file() and src_file.suffix.lower() in {".jpg", ".txt"}:
                rel_path = src_file.relative_to(source_dir)
                dst_file = (
                    target_dir
                    / rel_path.parent
                    / f"{rel_path.stem}{suffix}{rel_path.suffix}"
                )
                copy2(src_file, dst_file)
                if subclass and dst_file.suffix.lower() == ".txt":
                    remap_labels(dst_file)

# %%
# Display class prevelance
for subfolder in ["train2017", "val2017"]:
    print(subfolder)
    ann_meta, file_meta = get_metadata(subfolder=subfolder)
    display(ann_meta["class"].value_counts())
    display(file_meta.value_counts())
