# %%
import sys
import os

sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), os.pardir)))

# %%
from ultralytics import YOLO

import utils
from config import settings

# %%
device = utils.get_best_device()
data = os.path.join("..", "datasets", "coco_downsample.yaml")
model_original = YOLO("yolo26n.pt")

# %%
_ = model_original.val(
    data=data,
    classes=[0, 15],
    device=device,
)

# %%
_ = model_original.train(
    data=data,
    epochs=50,
    # fraction=0.01,
    batch=8,
    imgsz=settings.IMGSZ,
    device=device,
    # freeze=23,
    lr0=0.01,
    lrf=0.1,
    warmup_epochs=0,
    mosaic=0.0,
    classes=[0, 15],
    # warmup_bias_lr=0.0,
)

# %%
_ = model_original.val(
    data=data,
    classes=[0, 15],
    device=device,
)
